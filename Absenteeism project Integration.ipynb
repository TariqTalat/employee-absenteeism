# %%
from absenteeism_model import *

# %%
model = AbsenteeismModel('log_model.pkl')

# %%
processed_data = model.preprocess_data('Absenteeism_new_data.csv')
# Get predictions (0 or 1)
predictions = model.predict(processed_data)
# Get probabilities (likelihood of excessive absenteeism)
probabilities = model.predict_proba(processed_data)
# Add predictions and probabilities to the DataFrame
final_df = model.add_predictions(processed_data)
final_df.head(5)
# Out:
#    Reason_1  Reason_2  Reason_3  Reason_4  Transportation Expense  \
# 0         0       0.0         0         1               -0.326675
# 1         1       0.0         0         0                2.097580
# 2         0       0.0         0         1               -0.646357
# 3         0       0.0         0         1               -0.326675
# 4         1       0.0         0         0               -0.646357
#
#    Distance to Work       Age  Daily Work Load Average  Body Mass Index  \
# 0          0.064835 -0.877958                -2.227361        -1.419428
# 1          1.839269 -1.127910                -2.227361         0.294598
# 2         -0.890629 -0.378053                -2.227361        -0.133908
# 3         -0.208155  0.371804                -2.227361        -0.776668
# 4         -0.890629 -0.378053                -2.227361        -0.133908
#
#    Education  Children      Pets     Month  Day of the week  Prediction  \
# ...
